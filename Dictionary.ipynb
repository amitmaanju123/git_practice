# %% [markdown]
# # Distionary in python

# %%
A dictionary is a collection of key–value pairs in Python.
A dictionary is an unordered collection of items in Python.
Each value is accessed using its key, not by position (like in lists).

# %%
Keys are unique and immutable (like strings, numbers, tuples).
Values can be any Python object, even another dictionary.

# %%
#mutable
#keys are not duplicate
#keys are not mutable
#values are mutable

# %%
s={}

# %%
s={1,2,3,'rohit'}
type(s)
# Out:
# set

# %%
s={'a':10}
print(type(s))
s['a']
# Out:
# <class 'dict'>
# 10

# %%
s={'name':'amit'}
print(s)
# Out:
# {'name': 'amit'}

# %%
s['amit']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s['amit']
#
# KeyError: 'amit'

# %%
d={'name':'amit','age':21,'addr':'derabassi'}
d['age']
# Out:
# 21

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'addr'])

# %%
d.values()
# Out:
# dict_values(['amit', 21, 'derabassi'])

# %%
e={'name':['amit','mohit'],'age':[21,21]}
e
# Out:
# {'name': ['amit', 'mohit'], 'age': [21, 21]}

# %%
e['name']
# Out:
# ['amit', 'mohit']

# %%
#why we use dict
#Data with Meaningful Labels
[21,23]
{"amit": 21, "mohit": 30}
# 1 You can quickly find or modify data using its key:
#store and access data using keys instead of numeric indexes
#Fast Lookup (Search)
#  Accessing a value by its key is very fast (O(1) time)
#Data with Meaningful Labels
[21, 23]
{"amit": 21, "mohit": 23}
# Out:
# {'amit': 21, 'mohit': 23}

# %% [markdown]
# # representation of dict in dataframe

# %%
import pandas as pd
df=pd.DataFrame(e)
df
# Out:
#     name  age
# 0   amit   21
# 1  mohit   21

# %%
l=['amit','mohit']
l1=[36,30]
df=pd.DataFrame({'name':l,'age':l1})
df
# Out:
#     name  age
# 0   amit   36
# 1  mohit   30

# %%
df=pd.DataFrame(df,columns=['name','age'])
df
# Out:
#     name  age
# 0   amit   36
# 1  mohit   30

# %% [markdown]
# # conversion of dict in to list,set

# %%
d={'name':'amit','age':21,'addr':'derabassi'}

print(set(d))
print(list(d))
d.keys() #This  returns a view object of the dictionary keys.
d.values() #This returns a view object of the dictionary values.
# Out:
# {'addr', 'name', 'age'}
# ['name', 'age', 'addr']
# dict_values(['amit', 21, 'derabassi'])

# %%
for i in d.values():
    print(i)
# Out:
# amit
# 21
# derabassi

# %%
list(d.keys())  # ['name', 'age', 'addr']
set(d.keys())   # {'name', 'age', 'addr'}
# Out:
# {'addr', 'age', 'name'}

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}

# %%
# Accessing Values

# %%
#.get(key, default) returns the value for key if it exists, otherwise returns default

# %%
print(student["grade"])     # Output: Aarav
print(d.get("age"))  # Output: 21
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(student["grade"])     # Output: Aarav
#       2 print(d.get("age"))
#
# KeyError: 'grade'

# %%
# keyerror

# %%
#print(d["gra"])     #error
print(student.get("age"))  # Output: 21
# Out:
# 21

# %%
print(student.get("grade","N/A"))
# Out:
# N/A

# %% [markdown]
# # Adding & Updating Elements

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}

# %%
student["grade"] = "A"       # Add new key-value pair
student["age"] = 22          # Update existing value
print(student)
# Out:
# {'name': 'Aarav', 'age': 22, 'course': 'Computer Science', 'grade': 'A'}

# %%
#permanenet change
student["age"] = 22    assignment # add and update single key
.setdefault #add but not update
update  # update existing key and add new key (multiple keys) 
# create new dict
#packing

# %%
#assignment example
s= {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}
s['name']='amit'      #update
s
# Out:
# {'name': 'amit', 'age': 21, 'course': 'Computer Science'}

# %%
s['grade']='a' #add 
s
# Out:
# {'name': 'amit', 'age': 21, 'course': 'Computer Science', 'grade': 'a'}

# %%
#add but not update
s.setdefault("grade","b") # not update
s
# Out:
# {'name': 'ritu',
#  'age': 21,
#  'course': 'Computer Science',
#  'grade': 'a',
#  'address': 'karnal',
#  'mob': 8529,
#  'abc': 'xyz'}

# %%
s.setdefault("address","ambala") #add 
s
# Out:
# {'name': 'amit',
#  'age': 21,
#  'course': 'Computer Science',
#  'grade': 'a',
#  'address': 'ambala'}

# %%
# update existing key and add new key (multiple keys)
s.update({"address":"karnal"}) #update
s
# Out:
# {'name': 'amit',
#  'age': 21,
#  'course': 'Computer Science',
#  'grade': 'a',
#  'address': 'karnal'}

# %%
s.update({'mob':8529}) # add
s
# Out:
# {'name': 'amit',
#  'age': 21,
#  'course': 'Computer Science',
#  'grade': 'a',
#  'address': 'karnal',
#  'mob': 8529}

# %%
s.update({"address": "karnal", "name": "ritu","abc":'xyz'})
print(s)
# Out:
# {'name': 'ritu', 'age': 21, 'course': 'Computer Science', 'grade': 'a', 'address': 'karnal', 'mob': 8529, 'abc': 'xyz'}

# %% [markdown]
# # combine two dict

# %%
student = {"name": "Riya", "age": 23}
new_data = {"grade": "A", "city": "Delhi"}

merged = {**student, **new_data}
print(merged)
# Out:
# {'name': 'Riya', 'age': 23, 'grade': 'A', 'city': 'Delhi'}

# %%
d1= {"name": "Riya", "age": 23}
d2= {"grade": "A", "city": "Delhi"}
new=d1|d2
new
# Out:
# {'name': 'Riya', 'age': 23, 'grade': 'A', 'city': 'Delhi'}

# %%
a={"name":"amit","age":21}
b={"name":"mohit","age":21}
c=a|b
print(c)
# Out:
# {'name': 'mohit', 'age': 21}

# %%
# add multiple element in dict
but dictionaries themselves store only one value per key.

# %%
student = {"name": "Riya", "grades": [85, 90]}

# Add another grade
student["grades"].append(95)
print(student)
# Out:
# {'name': 'Riya', 'grades': [85, 90, 95]}

# %%
# add new key with multiple element using list
student["age"].append(95) #give error
print(student)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 # add new key with multiple element using list
# ----> 2 student["age"].append(95) #give error
#       3 print(student)
#
# KeyError: 'age'

# %%
#safe side
student = {"name": "Riya", "grades": [85, 90]}
student.setdefault("age", []).append(95)
student
# Out:
# {'name': 'Riya', 'grades': [85, 90], 'age': [95]}

# %%
student.setdefault("age", []).extend([95])
student
# Out:
# {'name': 'Riya', 'grades': [85, 90], 'age': [95, 95]}

# %%
student = {"name": "Riya", "grades": [85, 90]}

# %%
# do later
student["name"] = [student["name"]] if isinstance(student["name"], str) else student["name"]
print(student)
# Now append
student["name"].append('ritu')

print(student)
# Out:
# {'name': ['Riya'], 'grades': [85, 90]}
# {'name': ['Riya', 'ritu'], 'grades': [85, 90]}

# %%
# remove
pop(key) # if not available key error
pop(key,None) #safer side
popitem #randomnly pop any item
del partially and fully
clear  # empty a dict
# Out:
#   Cell In[41], line 5
#     del partially and fully
#         ^
# SyntaxError: cannot delete expression

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}
print(student.pop('name'))
# Out:
# Aarav

# %%
print(student)
# Out:
# {'age': 21, 'course': 'Computer Science'}

# %%
student.pop('name') # give key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 student.pop('name')
#
# KeyError: 'name'

# %%
student.pop('name',None) #SAFE SIDE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 student.pop('name',None)
#
# NameError: name 'student' is not defined

# %%
student.popitem()
# Out:
# ('course', 'Computer Science')

# %%
student
# Out:
# {'age': 21}

# %%
#want to delete multiple key in one go
student = {"name": "Renu", "age": 22, "city": "Karnal", "grade": "A"}

for key in ["age", "city"]:  
    student.pop(key, None)

print(student)
# Out:
# {'name': 'Renu', 'grade': 'A'}

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}
del student['name']

# %%
student
# Out:
# {'age': 21, 'course': 'Computer Science'}

# %%
student.clear()

# %%
del student

# %%
student
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 student
#
# NameError: name 'student' is not defined

# %% [markdown]
# # membership

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}
print("name" in student)
print(21 in student.values())
# Out:
# True
# True

# %% [markdown]
# # Looping Through a Dictionary

# %%
student = {
    "name": "Aarav",
    "age": 21,
    "course": "Computer Science"
}
student.items()
# Out:
# dict_items([('name', 'Aarav'), ('age', 21), ('course', 'Computer Science')])

# %%
for key in student:
    print(key, ":", student[key])
# Out:
# name : Aarav
# age : 21
# course : Computer Science

# %%
for key, value in student.items():
    print(key, "=", value)
# Out:
# name = Aarav
# age = 21
# course = Computer Science

# %%
for key in student.keys():
    print(key)
# Out:
# name
# age
# course

# %%
for value in student.values():
    print(value)
# Out:
# Aarav
# 21
# Computer Science

# %%
student.keys() # list output
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
student.values()
# Out:
# dict_values(['Aarav', 21, 'Computer Science'])

# %%
student.items()
# Out:
# dict_items([('name', 'Aarav'), ('age', 21), ('course', 'Computer Science')])

# %%
Nested Dictionaries

# %%
A nested dictionary is a dictionary where values themselves can be dictionaries 
(or even other collections like lists).

# %%
students has keys "student1", "student2"
# Out:
#   Cell In[63], line 1
#     students has keys "student1", "student2"
#              ^
# SyntaxError: invalid syntax

# %%
students = {
    "student1": {"name": "Renu", "age": 22},
    "student2": {"name": "Ritu", "age": 21}
}
print(students["student1"])
print(students["student1"]["name"])
# Out:
# {'name': 'Renu', 'age': 22}
# Renu

# %%
#update 
students["student2"]["city"] = "Noida"

# %%
# add new key value
students["student2"]["grade"] = "A"
print(students["student2"])
# Out:
# {'name': 'Ritu', 'age': 21, 'city': 'Noida', 'grade': 'A'}

# %%
# add new nested key
students["student3"] = {"name": "Ravi", "age": 20, "city": "Patiala"}
print(students["student3"])
# Out:
# {'name': 'Ravi', 'age': 20, 'city': 'Patiala'}

# %%
students
# Out:
# {'student1': {'name': 'Renu', 'age': 22},
#  'student2': {'name': 'Ritu', 'age': 21, 'city': 'Noida', 'grade': 'A'},
#  'student3': {'name': 'Ravi', 'age': 20, 'city': 'Patiala'}}

# %% [markdown]
# # merge the two dict

# %%
#If keys overlap, values from the second dictionary overwrite the first
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

merged = dict1 | dict2
print(merged)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
dict1.update(dict2) #dict1 is changed itself
print(dict1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
merged = {k: dict1.get(k, 0) + dict2.get(k, 0) for k in set(dict1) | set(dict2)}
print(merged)
# Out:
# {'a': 1, 'c': 0, 'b': 2}

# %%
a={"name":"amit","age":21}
b={"add":"derabassi","grade":"A"}

c={**a , **b}
print(c)
# Out:
# {'name': 'amit', 'age': 21, 'add': 'derabassi', 'grade': 'A'}

# %%
a={1:22,4:34}
b={"name":"amit","age":21}
c=a | b
print(c)
# Out:
# {1: 22, 4: 34, 'name': 'amit', 'age': 21}
