# %%
return

When you use return to give back a list (or any collection),
the entire list is created and stored in memory at once.

This can consume a lot of memory if the list is large.

➤ yield

When you use yield, the function becomes a generator.

It produces one value at a time, only when needed (lazy evaluation).

It doesn’t keep the entire sequence in memory — just the current state.

# %%
def counter():
    print("hello")
    print("second")
    return 
    print("hru")
counter()
# Out:
# hello
# second

# %%
def counter():
    for i in range(5):
        print(i)
    return
    print("after loop")
counter()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def counter():
    print("hello")
    yield 0 
    print("hru")
    yield 1
    print("welcomr")
    yield 2
counter()
# Out:
# <generator object counter at 0x0000020A6C421300>

# %%
gen=counter()
next(gen)  # runs untill first yield
# Out:
# hello
# 0

# %%
next(gen)
# Out:
# hru
# 1

# %%
def counter():
    for i in range(5):
        print(i)  #0
        yield("first yield",i)   #The function starts executing from the top.It hits yield 0:
        print("hello")   # Pauses execution.Sends the value before yield to the caller
counter()
# Out:
# <generator object counter at 0x0000020A6D9F86C0>

# %%
gen=counter()
next(gen)
# Out:
# 0
# ('first yield', 0)

# %%
def counter():
    for i in range(5):
        print(i)  #0 ,1,2
                   #The function starts executing from the top.It hits yield 0:
        print("hello")   # Pauses execution.Sends the value before yield to the caller
        yield
counter()
# Out:
# <generator object counter at 0x0000020A6D9F9150>

# %%
gen1=counter()
next(gen1)
# Out:
# 0
# hello

# %%
next(gen1)
# Out:
# 1
# hello

# %%
def counter():
    for i in range(5):
        print(i)
        print("first yield",i)
    yield    
counter()
# Out:
# <generator object counter at 0x0000020A6D9FA0C0>

# %%
gen2=counter()
next(gen2)
# Out:
# 0
# first yield 0
# 1
# first yield 1
# 2
# first yield 2
# 3
# first yield 3
# 4
# first yield 4

# %%
l=[1,2,3,4,5]
a=iter(l)
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 2

# %%
Each yield just defines what value is returned when you call next()
# Out:
#   Cell In[15], line 1
#     Each yield just defines what value is returned when you call next()
#          ^
# SyntaxError: invalid syntax

# %%
def counter():
    for i in range(5):
        print(i)
    yield ("stop")   #The function starts executing from the top.It hits yield 0:
    print("hello")   # Pauses execution.Sends the value before yield to the caller
counter()
# Out:
# <generator object counter at 0x0000020A6D9F93C0>

# %%
gen=counter()
next(gen)
# Out:
# 0
# 1
# 2
# 3
# 4
# 'stop'

# %%
def counter():
    for i in range(5):
        print(i)
        yield("first yield",i)
counter()
# Out:
# <generator object counter at 0x0000020A6D9F8FB0>

# %%
gen=counter()
gen
# Out:
# <generator object counter at 0x0000020A6D803D30>

# %%
next(gen)
# Out:
# 0
# ('first yield', 0)

# %%
next(gen)
# Out:
# 1
# ('first yield', 1)

# %%
def counter():
    for i in range(5):
        print(i)
        print("first yield",i)
    return    
counter()
# Out:
# 0
# first yield 0
# 1
# first yield 1
# 2
# first yield 2
# 3
# first yield 3
# 4
# first yield 4

# %%
gen=counter()
next(gen)
# Out:
# 0
# first yield 0
# 1
# first yield 1
# 2
# first yield 2
# 3
# first yield 3
# 4
# first yield 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 gen=counter()
# ----> 2 next(gen)
#
# TypeError: 'NoneType' object is not an iterator

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 next(gen)
#
# TypeError: 'NoneType' object is not an iterator

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 next(gen)
#
# TypeError: 'NoneType' object is not an iterator

# %%
When you use yield, the function becomes a generator.

It produces one value at a time
Creates new generator and runs until first yield

# %% [markdown]
# # diff between iterator and generator

# %%
def counter():
    print("hello")
    yield 0 
    print("hru")
    yield 1
counter()
# Out:
# <generator object counter at 0x0000020A6FD62E00>

# %%
#You need to iterate over that generator — for example using next() or a loop:
gen=counter()
next(gen)  # runs untill first yield
# Out:
# hello
# 0

# %%
next(gen)
# Out:
# hru
# 1

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
a=iter([1,2,3,4])
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 2

# %%
next(counter())
# Out:
# hello
# 0

# %%
a=greet()
print(a)

a

print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a=greet()
#       2 print(a)
#       4 a
#
# NameError: name 'greet' is not defined

# %%
def add_numbers(*x,y,z,a,b,f=3): # accept anly keyvalue pair 
    print( x , y,z,a,b,f)
add_numbers(10,20,y=20,z=3,a=4,b=4)
# Out:
# (10, 20) 20 3 4 4 3
